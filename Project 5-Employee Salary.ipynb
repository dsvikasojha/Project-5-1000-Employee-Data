# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv('1000 Records.csv')

# %%
ds.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial  Last Name Gender  \
# 0  850297         Ms.     Shawna              W       Buck      F
# 1  304721         Mr.  Nathaniel              Z      Burke      M
# 2  412317        Drs.  Elisabeth              W     Foster      F
# 3  621375        Mrs.     Briana              C  Lancaster      F
# 4  787549        Hon.    Estella              L     Potter      F
#
#                         E Mail      Father's Name     Mother's Name  \
# 0        shawna.buck@gmail.com       Rosario Buck       Keisha Buck
# 1  nathaniel.burke@walmart.com      Derrick Burke      Phoebe Burke
# 2   elisabeth.foster@gmail.com       Irwin Foster      Janie Foster
# 3   briana.lancaster@yahoo.com  Jeffrey Lancaster  Shelby Lancaster
# 4     estella.potter@gmail.com      Booker Potter    Katelyn Potter
#
#   Mother's Maiden Name  ...          SSN    Phone No.   Place Name  \
# 0            Hendricks  ...  222-11-7603  702-771-7149   Las Vegas
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age in Yrs.             1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %%
ds.isnull().sum()
# Out:
# Emp ID                    0
# Name Prefix               0
# First Name                0
# Middle Initial            0
# Last Name                 0
# Gender                    0
# E Mail                    0
# Father's Name             0
# Mother's Name             0
# Mother's Maiden Name      0
# Date of Birth             0
# Time of Birth             0
# Age in Yrs.               0
# Weight in Kgs.            0
# Date of Joining           0
# Quarter of Joining        0
# Half of Joining           0
# Year of Joining           0
# Month of Joining          0
# Month Name of Joining     0
# Short Month               0
# Day of Joining            0
# DOW of Joining            0
# Short DOW                 0
# Age in Company (Years)    0
# Salary                    0
# Last % Hike               0
# SSN                       0
# Phone No.                 0
# Place Name                0
# County                    0
# City                      0
# State                     0
# ...

# %%
ds.describe()
# Out:
#               Emp ID  Age in Yrs.  Weight in Kgs.  Year of Joining  \
# count    1000.000000  1000.000000     1000.000000      1000.000000
# mean   549097.583000    40.377250       59.409000      2006.992000
# std    264810.879315    11.107729       13.900322         8.565588
# min    114425.000000    21.040000       40.000000      1980.000000
# 25%    307757.000000    30.925000       49.000000      2002.000000
# 50%    543073.000000    40.730000       57.000000      2009.000000
# 75%    788450.250000    49.852500       68.000000      2014.000000
# max    999475.000000    59.980000       90.000000      2017.000000
#
#        Month of Joining  Day of Joining  Age in Company (Years)  \
# count       1000.000000     1000.000000             1000.000000
# mean           6.415000       16.481000               10.093720
# std            3.428488        8.831514                8.568863
# min            1.000000        1.000000                0.000000
# ...

# %%
ds.shape
# Out:
# (1000, 37)

# %%
ds['City'].unique()
# Out:
# array(['Las Vegas', 'Irons', 'Lexington', 'Munster', 'Fairbanks',
#        'Purcellville', 'Stowell', 'Herndon', 'Ocoee', 'Springfield',
#        'Montgomery', 'Pacoima', 'Canby', 'Van Nuys', 'Knoxville',
#        'Oklahoma City', 'Friant', 'Patuxent River', 'Reisterstown',
#        'New Baltimore', 'Herman', 'Hoquiam', 'Dodson', 'Sheldon',
#        'Sacramento', 'Friendship', 'Fresno', 'Burlingame', 'Arlee',
#        'Welaka', 'Bairoil', 'Tupelo', 'Little Rock', 'Shungnak',
#        'Victoria', 'Shinnston', 'Rossville', 'Bellerose', 'Fairview',
#        'Castleton', 'Austinville', 'Adams Basin', 'Lampeter',
#        'Keystone Heights', 'Eddyville', 'Listie', 'Blue Island',
#        'Ardenvoir', 'Terre Haute', 'Maysville', 'Amherst', 'Beaman',
#        'Tuckerman', 'Lakeview', 'Arlington', 'Liverpool', 'Escatawpa',
#        'Oaks', 'Rochester', 'Farmington', 'Seligman', 'Michigan City',
#        'Macon', 'Matthews', 'Plainfield', 'High Point', 'Atlanta',
# ...

# %%
ds['State'].unique()
# Out:
# array(['NV', 'MI', 'KY', 'IN', 'AK', 'VA', 'TX', 'TN', 'IL', 'PA', 'CA',
#        'OR', 'IA', 'OK', 'MD', 'NY', 'NE', 'WA', 'LA', 'ME', 'MT', 'FL',
#        'WY', 'AR', 'WV', 'MA', 'MS', 'MO', 'GA', 'NC', 'NJ', 'OH', 'KS',
#        'ID', 'NH', 'CT', 'CO', 'MN', 'AL', 'WI', 'ND', 'SD', 'UT', 'NM',
#        'AZ', 'DE', 'SC', 'VT', 'DC', 'RI'], dtype=object)

# %%
ds['Region'].unique()
# Out:
# array(['West', 'Midwest', 'South', 'Northeast'], dtype=object)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Name Prefix             1000 non-null   object
#  2   First Name              1000 non-null   object
#  3   Middle Initial          1000 non-null   object
#  4   Last Name               1000 non-null   object
#  5   Gender                  1000 non-null   object
#  6   E Mail                  1000 non-null   object
#  7   Father's Name           1000 non-null   object
#  8   Mother's Name           1000 non-null   object
#  9   Mother's Maiden Name    1000 non-null   object
#  10  Date of Birth           1000 non-null   object
#  11  Time of Birth           1000 non-null   object
#  12  Age in Yrs.             1000 non-null   float64
#  13  Weight in Kgs.          1000 non-null   int64
# ...

# %%
ds=ds.drop(['Name Prefix','First Name','Middle Initial','Last Name','E Mail',"Father's Name","Mother's Name",
           "Mother's Maiden Name",'Date of Birth','Time of Birth'],axis=1)

# %%
ds=ds.drop(['Weight in Kgs.', 'Date of Joining', 'Half of Joining'],axis=1)

# %%
ds=ds.drop(['Month Name of Joining', 'Short Month', 'Day of Joining', 'DOW of Joining', 'SSN', 'Place Name','Zip','User Name','Password'
],axis=1)

# %%
sns.pairplot(ds)

# %%
ds
# Out:
#      Emp ID Gender  Age in Yrs. Quarter of Joining  Year of Joining  \
# 0    850297      F        45.66                 Q4             2010
# 1    304721      M        23.76                 Q2             2017
# 2    412317      F        22.68                 Q1             2017
# 3    621375      F        41.70                 Q1             2003
# 4    787549      F        22.39                 Q4             2016
# ..      ...    ...          ...                ...              ...
# 995  568435      F        32.01                 Q1             2008
# 996  597409      M        30.48                 Q1             2010
# 997  359608      F        59.88                 Q1             2001
# 998  803426      F        30.21                 Q1             2012
# 999  669618      F        59.78                 Q1             1980
#
#      Month of Joining Short DOW  Age in Company (Years)  Salary Last % Hike  \
# ...

# %%
ds=ds.drop('Phone No. ',axis=1)

# %%
ds
# Out:
#      Emp ID Gender  Age in Yrs. Quarter of Joining  Year of Joining  \
# 0    850297      F        45.66                 Q4             2010
# 1    304721      M        23.76                 Q2             2017
# 2    412317      F        22.68                 Q1             2017
# 3    621375      F        41.70                 Q1             2003
# 4    787549      F        22.39                 Q4             2016
# ..      ...    ...          ...                ...              ...
# 995  568435      F        32.01                 Q1             2008
# 996  597409      M        30.48                 Q1             2010
# 997  359608      F        59.88                 Q1             2001
# 998  803426      F        30.21                 Q1             2012
# 999  669618      F        59.78                 Q1             1980
#
#      Month of Joining Short DOW  Age in Company (Years)  Salary Last % Hike  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
ds['Gender']=le.fit_transform(ds['Gender'])

# %%
ds['Quarter of Joining']=le.fit_transform(ds['Quarter of Joining'])

# %%
ds['Short DOW']=le.fit_transform(ds['Short DOW'])

# %%
ds['County']=le.fit_transform(ds['County'])

# %%
ds['City']=le.fit_transform(ds['City'])

# %%
ds['State']=le.fit_transform(ds['State'])

# %%
ds['Region']=le.fit_transform(ds['Region'])

# %%
ds['Last % Hike']=le.fit_transform(ds['Last % Hike'])

# %%
ds
# Out:
#      Emp ID  Gender  Age in Yrs.  Quarter of Joining  Year of Joining  \
# 0    850297       0        45.66                   3             2010
# 1    304721       1        23.76                   1             2017
# 2    412317       0        22.68                   0             2017
# 3    621375       0        41.70                   0             2003
# 4    787549       0        22.39                   3             2016
# ..      ...     ...          ...                 ...              ...
# 995  568435       0        32.01                   0             2008
# 996  597409       1        30.48                   0             2010
# 997  359608       0        59.88                   0             2001
# 998  803426       0        30.21                   0             2012
# 999  669618       0        59.78                   0             1980
#
#      Month of Joining  Short DOW  Age in Company (Years)  Salary  Last % Hike  \
# ...

# %%
dscorr=ds.corr()

# %%
dscorr
# Out:
#                           Emp ID    Gender  Age in Yrs.  Quarter of Joining  \
# Emp ID                  1.000000  0.064168    -0.028516            0.004129
# Gender                  0.064168  1.000000    -0.013794            0.016359
# Age in Yrs.            -0.028516 -0.013794     1.000000            0.020401
# Quarter of Joining      0.004129  0.016359     0.020401            1.000000
# Year of Joining         0.039009  0.047214    -0.676875           -0.032659
# Month of Joining        0.000999  0.015040     0.022617            0.971525
# Short DOW               0.002980  0.062954     0.018045           -0.059249
# Age in Company (Years) -0.039064 -0.047735     0.676408            0.000146
# Salary                 -0.027248  0.050883     0.041422           -0.015299
# Last % Hike            -0.011497 -0.021617     0.043050           -0.015245
# County                 -0.025864  0.028121    -0.009495           -0.061764
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(dscorr,annot=True)
# Out:
# <AxesSubplot:>

# %%
ds.plot(kind='box',subplots=True,layout=(5,15),figsize=(20,40))
# Out:
# Emp ID                       AxesSubplot(0.125,0.749828;0.0435393x0.130172)
# Gender                    AxesSubplot(0.177247,0.749828;0.0435393x0.130172)
# Age in Yrs.               AxesSubplot(0.229494,0.749828;0.0435393x0.130172)
# Quarter of Joining        AxesSubplot(0.281742,0.749828;0.0435393x0.130172)
# Year of Joining           AxesSubplot(0.333989,0.749828;0.0435393x0.130172)
# Month of Joining          AxesSubplot(0.386236,0.749828;0.0435393x0.130172)
# Short DOW                 AxesSubplot(0.438483,0.749828;0.0435393x0.130172)
# Age in Company (Years)     AxesSubplot(0.49073,0.749828;0.0435393x0.130172)
# Salary                    AxesSubplot(0.542978,0.749828;0.0435393x0.130172)
# Last % Hike               AxesSubplot(0.595225,0.749828;0.0435393x0.130172)
# County                    AxesSubplot(0.647472,0.749828;0.0435393x0.130172)
# City                      AxesSubplot(0.699719,0.749828;0.0435393x0.130172)
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Emp ID                  1000 non-null   int64
#  1   Gender                  1000 non-null   int32
#  2   Age in Yrs.             1000 non-null   float64
#  3   Quarter of Joining      1000 non-null   int32
#  4   Year of Joining         1000 non-null   int64
#  5   Month of Joining        1000 non-null   int64
#  6   Short DOW               1000 non-null   int32
#  7   Age in Company (Years)  1000 non-null   float64
#  8   Salary                  1000 non-null   int64
#  9   Last % Hike             1000 non-null   int32
#  10  County                  1000 non-null   int32
#  11  City                    1000 non-null   int32
#  12  State                   1000 non-null   int32
#  13  Region                  1000 non-null   int32
# ...

# %%
ds.shape
# Out:
# (1000, 14)

# %%
from scipy.stats import zscore
z=np.abs(zscore(ds))
z
# Out:
# array([[1.13798244, 1.01816496, 0.47583025, ..., 0.10975581, 0.52610404,
#         1.49185658],
#        [0.92329614, 0.98215912, 1.49675646, ..., 0.29981602, 0.24737156,
#         1.32296716],
#        [0.51678022, 1.01816496, 1.59403471, ..., 0.05828117, 0.59895138,
#         0.553582  ],
#        ...,
#        [0.71592375, 1.01816496, 1.75666052, ..., 1.46220048, 1.44274295,
#         1.49185658],
#        [0.96089586, 1.01816496, 0.91578914, ..., 1.26026151, 1.30211102,
#         0.38469258],
#        [0.45534656, 1.01816496, 1.74765327, ..., 0.17137491, 0.73705194,
#         0.553582  ]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([594, 594, 606, 621, 621, 684, 684, 895, 999, 999], dtype=int64), array([4, 7, 4, 4, 7, 4, 7, 4, 4, 7], dtype=int64))

# %%
ds_new=ds[(z<3).all(axis=1)]

# %%
ds_new
# Out:
#      Emp ID  Gender  Age in Yrs.  Quarter of Joining  Year of Joining  \
# 0    850297       0        45.66                   3             2010
# 1    304721       1        23.76                   1             2017
# 2    412317       0        22.68                   0             2017
# 3    621375       0        41.70                   0             2003
# 4    787549       0        22.39                   3             2016
# ..      ...     ...          ...                 ...              ...
# 994  172440       1        28.61                   1             2017
# 995  568435       0        32.01                   0             2008
# 996  597409       1        30.48                   0             2010
# 997  359608       0        59.88                   0             2001
# 998  803426       0        30.21                   0             2012
#
#      Month of Joining  Short DOW  Age in Company (Years)  Salary  Last % Hike  \
# ...

# %%
ds_new.shape
# Out:
# (994, 14)

# %%
ploss=((6)/1000)*100
ploss
# Out:
# 0.6

# %%
ds_new.skew()
# Out:
# Emp ID                    0.027949
# Gender                   -0.040310
# Age in Yrs.               0.008416
# Quarter of Joining        0.042423
# Year of Joining          -0.910888
# Month of Joining          0.055024
# Short DOW                 0.071843
# Age in Company (Years)    0.918974
# Salary                    0.037302
# Last % Hike               0.011012
# County                   -0.002295
# City                      0.012612
# State                     0.006850
# Region                   -0.073613
# dtype: float64

# %%
for i in ds.columns:
    plt.figure()
    sns.distplot(ds_new[i])

# %%
x = ds_new[['Emp ID','Gender','Age in Yrs.','Quarter of Joining','Year of Joining','Month of Joining','Short DOW','Age in Company (Years)','Last % Hike','County','City', 'State','Region']]

# %%
y=ds_new.iloc[:,8]

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(ds_new,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
lr=LinearRegression()

# %%
best_rstate=0
accu=0
for i in range(30,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i

print(f"Best Accuracy {accu *100} found on random_state {best_rstate}")
# Out:
# Best Accuracy 99.73056485974162 found on random_state 163

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=163)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.9968942973420115

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls = Lasso(alpha=10,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9968877005401258

# %%
import joblib

# %%
joblib.dump(lr,'1000 Employee Salary.pkl')
# Out:
# ['1000 Employee Salary.pkl']
